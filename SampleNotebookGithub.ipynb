# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
df = spark.read.table('dev_sandbox.bbagorio_sandbox.employeenames')
df.show()

# %%
dfilter = df.filter(df.Age > 30)
dfilter.show()
